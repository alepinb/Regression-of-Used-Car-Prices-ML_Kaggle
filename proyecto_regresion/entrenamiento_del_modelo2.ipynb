# %% [markdown]
# ## Carga de librerías

# %%
import pandas as pd
import os
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
import numpy as np

# %% [markdown]
# ## Carga de datos X_train_features.csv, y_train y X_test y  mostrar primeras filas del dataset

# %%
ruta_absoluta = os.path.abspath(r'C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\X_train_features5.csv')
print(ruta_absoluta)

X_features = pd.read_csv(ruta_absoluta)

ruta_absoluta = os.path.abspath(r'C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\y_train5.csv')
print(ruta_absoluta)

y_train = pd.read_csv(ruta_absoluta)

ruta_absoluta = os.path.abspath(r'C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\X_test_clean5.csv')
print(ruta_absoluta)

X_test_orig = pd.read_csv(ruta_absoluta)

ruta_absoluta = os.path.abspath(r'C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\playground-series-s4e9\test.csv')
print(ruta_absoluta)

X_test_id = pd.read_csv(ruta_absoluta)



# Mostrar las primeras filas del DataFrame
print(X_features.head())
print(X_test.head())
# Out:
# C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\X_train_features5.csv
# C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\y_train5.csv
# C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\X_test_clean5.csv
# C:\Users\Administrator\Documents\Proyecto regresion precio coches\proyecto_regresion\data\playground-series-s4e9\test.csv
#       brand     model    milage  fuel_type  transmission   ext_col   int_col  \
# 0  0.598002 -0.713392  2.957842  -0.101378      0.641293  1.355673  1.117717
# 1  0.480451  0.120255  1.557184  -0.101378      0.641293  0.927742 -0.613244
# 2 -0.930160  1.356353  1.426276  -1.411216      0.641293 -1.037247  1.117717
# 3  1.068206 -0.209371 -0.927854  -0.101378      1.487409 -1.115847 -0.499738
# 4  0.833104  0.401970 -1.171076  -0.101378     -0.512503 -1.115847 -0.613244
#
# ...

# %%
print(f"Forma de X_features: {X_features.shape}")
print(f"Longitud de y_train: {len(y_train)}")
print(f"Forma de X_test: {X_test_orig.shape}")
# Out:
# Forma de X_features: (188533, 12)
# Longitud de y_train: 188533
# Forma de X_test: (125690, 12)

# %% [markdown]
# ## Validación cruzada de GradientBoostRegressor

# %%
import numpy as np
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Definir el modelo
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)

# Dividir el conjunto de datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_features, y_train, test_size=0.2, random_state=42)

# Aplanar los vectores de etiquetas si es necesario
y_train = y_train.values.ravel()  # Convertir a un array 1D
y_test = y_test.values.ravel()

# Realizar la validación cruzada (en el conjunto de entrenamiento)
scores = cross_val_score(gb_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# Convertir los scores a MSE positivo
mean_mse = -scores.mean()
std_dev_mse = scores.std()

# Ajustar el modelo en el conjunto de entrenamiento
gb_model.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred_gb = gb_model.predict(X_test)

# Calcular métricas en el conjunto de prueba
mse = mean_squared_error(y_test, y_pred_gb)
r2 = r2_score(y_test, y_pred_gb)

# Mostrar resultados
print("Scores de validación cruzada (neg_mean_squared_error):", scores)
print("MSE promedio de validación cruzada:", mean_mse)
print("Desviación estándar de MSE:", std_dev_mse)
print("MSE en conjunto de prueba:", mse)
print("R² en conjunto de prueba:", r2)
# Out:
# Scores de validación cruzada (neg_mean_squared_error): [-4.31459727e+09 -6.63864099e+09 -4.72724422e+09 -5.73426304e+09
#  -6.35814387e+09]
# MSE promedio de validación cruzada: 5554577877.32835
# Desviación estándar de MSE: 902799065.171237
# MSE en conjunto de prueba: 4653947077.483774
# R² en conjunto de prueba: 0.16313012175509867

# %%
print(f"Forma de X_features: {X_features.shape}")
print(f"Longitud de y_train: {len(y_train)}")
# Out:
# Forma de X_features: (188533, 12)
# Longitud de y_train: 188533

# %% [markdown]
# ## Regresion lineal

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Supongamos que X_features es tu DataFrame con las características y y_train es tu Serie o DataFrame con las etiquetas
# X_features = pd.DataFrame(...)  # Tus características
# y_train = pd.Series(...)  # Tus precios de coches

# Dividir el conjunto de datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_features, y_train, test_size=0.2, random_state=42)

# Inicializar el modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo con los datos de entrenamiento
model.fit(X_train, y_train)

# Realizar predicciones con los datos de prueba
y_pred = model.predict(X_test)

# Calcular métricas
mse = mean_squared_error(y_test, y_pred)  # Error cuadrático medio
r2 = r2_score(y_test, y_pred)  # Coeficiente de determinación

# Mostrar los resultados
print("Error Cuadrático Medio (MSE):", mse)
print("Coeficiente de Determinación (R²):", r2)
# Out:
# Error Cuadrático Medio (MSE): 4886012271.208793
# Coeficiente de Determinación (R²): 0.12140030248896794

# %% [markdown]
# ## Random forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Supongamos que X_features es tu DataFrame con las características y y_train es tu Serie o DataFrame con las etiquetas
# X_features = pd.DataFrame(...)  # Tus características
# y_train = pd.Series(...)  # Tus precios de coches

# Dividir el conjunto de datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_features, y_train, test_size=0.2, random_state=42)

# Inicializar el modelo de Random Forest
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Entrenar el modelo con los datos de entrenamiento
model.fit(X_train, y_train.values.ravel())  # Asegurar que y_train sea un array 1D

# Realizar predicciones con los datos de prueba
y_pred = model.predict(X_test)

# Evaluar el rendimiento del modelo
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Mostrar los resultados
print("Error Cuadrático Medio (MSE):", mse)
print("Coeficiente de Determinación (R²):", r2)

# Mostrar la importancia de las características
importances = model.feature_importances_
feature_importance_df = pd.DataFrame(importances, index=X_features.columns, columns=['Importancia'])
feature_importance_df = feature_importance_df.sort_values(by='Importancia', ascending=False)

print("\nImportancia de las características:")
print(feature_importance_df)
# Out:
# Error Cuadrático Medio (MSE): 5576534391.722897
# Coeficiente de Determinación (R²): -0.00276895713065084
#
# Importancia de las características:
#                        Importancia
# milage                    0.341675
# ext_col                   0.117098
# model                     0.107014
# age                       0.096146
# extracted_horsepower      0.080969
# transmission              0.067356
# int_col                   0.066841
# extracted_engine_size     0.054181
# brand                     0.032521
# fuel_type                 0.013369
# transmission_type         0.011772
# accident                  0.011057

# %%
print(f"Forma de X_features: {X_features.shape}")
print(f"Longitud de y_train: {len(y_train)}")
# Out:
# Forma de X_features: (188533, 12)
# Longitud de y_train: 188533

# %% [markdown]
# ## Lasso y Ridge

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score

# Supongamos que X_features es tu DataFrame con las características y y_train es tu Serie o DataFrame con las etiquetas
# X_features = pd.DataFrame(...)  # Tus características
# y_train = pd.Series(...)  # Tus precios de coches

# Dividir el conjunto de datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_features, y_train, test_size=0.2, random_state=42)

# Inicializar el modelo de regresión Lasso
model = Lasso(alpha=0.1)  # Puedes ajustar el valor de alpha según tus necesidades

# Entrenar el modelo con los datos de entrenamiento
model.fit(X_train, y_train)

# Realizar predicciones con los datos de prueba
y_pred = model.predict(X_test)  # Usar el modelo para hacer predicciones sobre X_test

# Evaluar el rendimiento del modelo
mse_lasso = mean_squared_error(y_test, y_pred)  # Calcular el MSE
r2_lasso = r2_score(y_test, y_pred)  # Calcular R²

# Mostrar los resultados
print("Error Cuadrático Medio (MSE):", mse_lasso)
print("Coeficiente de Determinación (R²):", r2_lasso)

# Mostrar los coeficientes del modelo
lasso_coefficients = pd.DataFrame(model.coef_, X_features.columns, columns=['Coeficientes'])
print("\nCoeficientes de la Regresión Lasso:")
print(lasso_coefficients)
# Out:
# Error Cuadrático Medio (MSE): 4886012629.6517105
# Coeficiente de Determinación (R²): 0.12140023803398459
#
# Coeficientes de la Regresión Lasso:
#                        Coeficientes
# brand                   2877.480193
# model                   -684.283638
# milage                -14526.918292
# fuel_type              -3040.243081
# transmission             226.479885
# ext_col                 -596.920951
# int_col                 1782.060724
# accident                1948.570491
# age                    -3558.563108
# extracted_horsepower   13235.813010
# extracted_engine_size   -866.428907
# transmission_type       -625.218863

# %%
print(f"Forma de X_features: {X_features.shape}")
print(f"Longitud de y_train: {len(y_train)}")
# Out:
# Forma de X_features: (188533, 12)
# Longitud de y_train: 188533

# %% [markdown]
# ## XGBRegressor

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Supongamos que ya tienes las características y las etiquetas
# X_features = pd.DataFrame(...)  # Tus características
# y_train = pd.Series(...)  # Tus precios de coches

# Dividir los datos en conjunto de entrenamiento y de prueba
X_train, X_test, y_train, y_test = train_test_split(X_features, y_train, test_size=0.2, random_state=42)

# Inicializar el modelo XGBRegressor
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror', 
                           n_estimators=100,  # Número de árboles/iteraciones
                           learning_rate=0.1,  # Tasa de aprendizaje
                           max_depth=6,        # Profundidad máxima de los árboles
                           random_state=42)

# Entrenar el modelo
xgb_reg.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = xgb_reg.predict(X_test)

# Evaluar el rendimiento del modelo usando el error cuadrático medio
mse = mean_squared_error(y_test, y_pred)
print(f"Error cuadrático medio (MSE): {mse}")

# Si quieres imprimir algunas predicciones:
print(f"Algunas predicciones: {y_pred[:5]}")
# Out:
# Error cuadrático medio (MSE): 4705293447.902528
# Algunas predicciones: [50816.598 42154.008 33231.707 22983.184 37771.1  ]

# %% [markdown]
# ## Buscar hiperparametros con optuna XGBRegressor

# %%
import optuna
from xgboost import XGBRegressor

X_train, X_test, y_train, y_test = train_test_split(X_features, y_train, test_size= 0.3, random_state= 42)

eval_set = [(X_train, y_train), (X_test, y_test)]


# Definición del espacio de búsqueda para XGBRegressor
def objective_xgb(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'reg_alpha': trial.suggest_int('reg_alpha', 0, 10),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1),
        'subsample': trial.suggest_float('subsample', 0.5, 1),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10)
    }

    # Create and fit the model
    model = XGBRegressor(**params, eval_metric='rmse', use_label_encoder=False)
    model.fit(X_train, y_train, verbose=False)
    
    # Predict and calculate the mean squared error
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    
    return mse

# Execute the optimization for XGBRegressor using Optuna
study_xgb = optuna.create_study(direction='minimize')
study_xgb.optimize(objective_xgb, n_trials=100)

# Retrieve the best hyperparameters for XGBRegressor
best_xgb_params = study_xgb.best_params
best_xgb_score = study_xgb.best_value

print('Mejores hiperparámetros para XGB:', best_xgb_params)
print('Mejor puntaje (MSE):', best_xgb_score)

# Create a new XGBRegressor with the best hyperparameters
best_xgb = XGBRegressor(**best_xgb_params, eval_metric='rmse', use_label_encoder=False)

# Train the model using the best hyperparameters
best_xgb.fit(X_train, y_train)
# Out:
# [I 2024-10-01 12:12:03,278] A new study created in memory with name: no-name-0c845f1d-db1b-483c-8f27-4c2cb60eb3e8
# c:\Users\Administrator\Documents\Proyecto regresion precio coches\myenv\Lib\site-packages\xgboost\core.py:158: UserWarning: [12:12:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-10-01 12:12:04,895] Trial 0 finished with value: 4572198033.78435 and parameters: {'n_estimators': 182, 'max_depth': 5, 'gamma': 2.994393698915749, 'reg_alpha': 6, 'reg_lambda': 1.5849903606940585, 'min_child_weight': 2, 'colsample_bytree': 0.9030145134588932, 'subsample': 0.9016792413746737, 'learning_rate': 0.1950685077273291, 'scale_pos_weight': 2.777686239286306}. Best is trial 0 with value: 4572198033.78435.
# ...

# %% [markdown]
# ## Predecir y_test

# %%
# Realizar las predicciones con el modelo entrenado
y_test_predictions = best_xgb.predict(X_test_orig)

# Mostrar algunas de las predicciones
print(f"Predicciones para X_test: {y_test_predictions[:5]}")

# Si tienes y_test y deseas evaluar el rendimiento
# from sklearn.metrics import mean_squared_error
# test_mse = mean_squared_error(y_test, y_test_predictions)
# print(f"MSE en el conjunto de prueba: {test_mse}")
# Out:
# Predicciones para X_test: [21821.848 69598.55  83959.305 27096.828 31556.498]

# %% [markdown]
# ## Unir y_test con la columna "id"

# %%
# Crear un DataFrame con la columna 'id' de X_test
id_column = X_test_id[['id']].copy()



# Convertir las predicciones de y_test_predictions en un DataFrame
predictions_df = pd.DataFrame(y_test_predictions, columns=['predicted_price'])

# Concatenar la columna 'id' con las predicciones
output = pd.concat([id_column, predictions_df], axis=1)

# Verificar que el número de filas es 125,690
assert len(output) == 125690, f"El número de filas es {len(output)}, pero debe ser 125690."

# Guardar el archivo en formato CSV
output.to_csv('submission_N.csv', index=False)


print("Archivo guardado exitosamente.")
# Out:
# Archivo guardado exitosamente.
